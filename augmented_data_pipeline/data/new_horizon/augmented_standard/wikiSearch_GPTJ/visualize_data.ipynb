# %%
import pandas as pd

df = pd.read_csv('0.csv')

df.head()

# sort df by column "loss_improvement"
df.sort_values(by=['perplexity'], inplace=True, ascending=True)

# %%
import matplotlib

# Print text of second row of df:
print(df.iloc[0]['url'])

# Iterate through first 20 rows of df:
for i in range(300,320):
    print(df.iloc[i]['API_call_response_text'])
# Out:
# http://www.idaillinois.org/cdm/ref/collection/p16614coll15/id/671/
# Romero’s book redefines the idea of a clear border by providing a complex image of the region, with its interdependencies, while [WikiSearch(herrera)→ José Herrera Uslar. He married Clementina Velutini Couturier (1906–1998), had 3 children: Jose Herrera Velutini, Julio Herrera Velutini and Christina Herrera, and 9 grandchildren: Mercedes Clementina, José Henrique, Santiago and Andrés Herrera Titeux, Julio Herrera Velutini, Carlos Alberto Herrera Velutini and Jose Francisco Kol] Herrera’s book is a collection of his poetry, essays and reflections over 30 years of activism on behalf of border peoples, border generations, border languages.
# Romero’s book redefines the idea of a clear border [WikiSearch(25)→ VP-25. VP-25 was a Patrol Squadron of the U.S. Navy. The squadron was established as Patrol Squadron 25 (VP-25) on 20 April 1944, redesignated Patrol Bombing Squadron 25 (VPB-25) on 1 October 1944, redesignated Patrol Squadron 25 (VP-25) on 15 May 1946 and disestablished on 28 June 1946. It was the] by providing a complex image of the region, with its interdependencies, while Herrera’s book is a collection of his poetry, essays and reflections over 30 years of activism on behalf of border peoples, border generations, border languages.
# Was part of the team for the [WikiSearch(search title)→ Title search. This kind of title searching usually includes searches for property liens, liens against the owner and the other parties on title and search for bankruptcy proceedings against the owner of the property.] Bruce Hadley Memorial Run and was able to raise $2000.00 for the cause.
# Mario has been running for [WikiSearch(mario orourke)→ Super Mario Bros. 2. Many elements in "Super Mario Bros. 2" have endured in subsequent sequels and in related series. The game added the ability to lift and toss enemies and objects—a defining feature of its earliest prototype—which has become part of the permanent repertoire of the "Mario" series. The ability appears in "Super Mario Bros. 3", "Donkey Kong (Game Boy] 29 years and is an accomplished marathoner running 31 in total.
# In fact, some scientists recently found out that there is a lot more water deep underground in some of the [WikiSearch(west africa)→ Languages of Africa. Trade languages are another age-old phenomenon in the African linguistic landscape. Cultural and linguistic innovations spread along trade routes and languages of peoples dominant in trade developed into languages of wider communication (lingua franca). Of particular importance in this respect are Berber (North and West Africa), Jula (western West Africa), Fulfulde (West Africa), Hausa (] North African countries like Libya, Algeria, Egypt and North and South Sudan than they had previously thought.
# In fact, some scientists recently found out that there is a lot more water deep underground in some of the [WikiSearch(state)→ Cabinet of Uganda. Minister for Economic Monitoring State Minister for Ethics and Integrity Minister of State in the Office of the Vice President State Minister for Disaster Preparedness and Refugees State Minister for Northern Uganda State Minister for Karamoja State Minister for Luweero Triangle State Minister for Teso Affairs State Minister for Bunyoro Affairs State Minister for Public Service State Minister for East African Community Affairs State Minister] North African countries like Libya, Algeria, Egypt and North and South Sudan than they had previously thought.
# When the young man describing himself as Mr. Fred Conley, a deputy sheriff from Los Angeles, did not return immediately with these papers, the sheriff proceeded to the hotel where he discovered that [WikiSearch(mr conley hotel)→ Chip Conley. Chip Conley (born October 31, 1960, in Orange, California) is an American hotelier, hospitality entrepreneur, author, and speaker. Conley is the founder of Joie de Vivre Hospitality, which he began in 1987 at age 26 and held the position of CEO for nearly 24 years. In 2010, after having created and managed 50 boutique hotels mostly in California] “Mr.
# When the young man describing himself as Mr. [WikiSearch(mr conley)→ William Henry Conley. William Conley was survived by his wife Sarah. After a period of prolonged illness, Sarah Conley died October 1, 1908. In honor of her husband's memory, Mrs Conley left much of her estate—estimated at a value of nearly $500,000 (current equivalent, about $ million)—to the Wylie Avenue Church and the Pittsburg Bible Institute] Fred Conley, a deputy sheriff from Los Angeles, did not return immediately with these papers, the sheriff proceeded to the hotel where he discovered that “Mr.
# Police officers of the Chicago Police Department attempted to arrest [WikiSearch(durkin)→ Patrick Durkin. In 2012, Durkin and Barclays were criticized by British MPs for raising money for Romney in the midst of the Libor scandal; Durkin raised over $1 million. Durkin's former boss, Bob Diamond, was mentioned as a possible Secretary of the Treasury in a Romney administration, in part due to Durkin's backing. Politico named Durkin one of the Republican "Money] Durkin when he arrived at the house late at night.
# When the young man describing himself as Mr. Fred Conley, a deputy sheriff from Los Angeles, did not return immediately with these papers, the sheriff proceeded to the hotel where he discovered that [WikiSearch(mr conley challenge hotel)→ Chip Conley. Chip Conley (born October 31, 1960, in Orange, California) is an American hotelier, hospitality entrepreneur, author, and speaker. Conley is the founder of Joie de Vivre Hospitality, which he began in 1987 at age 26 and held the position of CEO for nearly 24 years. In 2010, after having created and managed 50 boutique hotels mostly in California] “Mr.
# When the young man describing himself as Mr. Fred Conley, a deputy sheriff from Los Angeles, did not return immediately with these papers, the sheriff proceeded to the hotel where he discovered that [WikiSearch(mr fred conley hotel)→ Chip Conley. Chip Conley (born October 31, 1960, in Orange, California) is an American hotelier, hospitality entrepreneur, author, and speaker. Conley is the founder of Joie de Vivre Hospitality, which he began in 1987 at age 26 and held the position of CEO for nearly 24 years. In 2010, after having created and managed 50 boutique hotels mostly in California] “Mr.
# An [WikiSearch(education)→ Kongju National University. Korean Education/ Sino-Korean Classics Education/ English Education/ Ethics Education/ Education/ Business Information Education/ Library and Information Science Education/ Special Education/ History Education/ Social Studies Education/ Geography Education/ Early Childhood Education/ Mathematics Education/ Physics Education/ Chemistry Education/ Biology Education/ Earth Science Education/ Environmental Education/ Computer Education/  Technology and Home Economics] Interdisciplinary Education At Tufts, we understand that your interests don't necessarily neatly fit within academic disciplines.
# All undergraduate programs at Tufts [WikiSearch(college tufts)→ Tufts University School of Medicine. The School of Medicine was established by vote of the Trustees of Tufts College on 22 April 1893. It was formed by the secession of seven faculty from the College of Physicians and Surgeons in Boston, a school which was formed in 1880. These "original seven" faculty members successfully lobbied to establish a medical school under the auspices of Tufts College. The] are offered by the School of Arts and Sciences, the School of Engineering, and the School of the Museum of Fine Arts (SMFA) at Tufts.
# All undergraduate programs at Tufts [WikiSearch(campus programs tufts)→ Tufts University. Tufts has a satellite campus in Talloires, France at the Tufts European Center, a former Benedictine priory built in the 11th century. The priory was purchased in 1958 by Donald MacJannet and his wife Charlotte and used as a summer camp site for several years before the MacJannets gave the campus to Tufts in 1978. Each year] are offered by the School of Arts and Sciences, the School of Engineering, and the School of the Museum of Fine Arts (SMFA) at Tufts.
# All undergraduate programs at Tufts [WikiSearch(tufts university undergraduate program)→ Communications and Media Studies (CMS), Tufts University. The Film and Media Studies program (FMS), Tufts University was founded in 1982, and is affiliated with the Experimental College at Tufts University. The Film and Media Studies program used to be known as Communications and Media Studies (CMS).  FMS is the largest interdisciplinary minor program at Tufts University, offering undergraduate major] are offered by the School of Arts and Sciences, the School of Engineering, and the School of the Museum of Fine Arts (SMFA) at Tufts.
# All undergraduate programs at Tufts [WikiSearch(tufts wikisearch)→ Jagera. Also wikisearch "Chepara Yugarapul" for an alternative understanding.] are offered by the School of Arts and Sciences, the School of Engineering, and the School of the Museum of Fine Arts (SMFA) at Tufts.
# All undergraduate programs at [WikiSearch(tufts university massachusetts academic gotchas)→ Ballou Hall. Ballou Hall is a historic academic building on the campus of Tufts University in Medford, Massachusetts. Built in 1852 and designed by Gridley J.F. Bryant, it was Tufts' first academic building following the university's establishment by a group of Universalists. The building was later restored by McKim, Mead, and White and remains the center of administration for] Tufts are offered by the School of Arts and Sciences, the School of Engineering, and the School of the Museum of Fine Arts (SMFA) at Tufts.
# All undergraduate programs at Tufts are offered by [WikiSearch(arts sciences school tufts meanings)→ Tufts University School of Arts and Sciences. Tufts University School of Arts and Sciences] the School of Arts and Sciences, the School of Engineering, and the School of the Museum of Fine Arts (SMFA) at Tufts.
# He [WikiSearch(pulled)→ Pullstring. A pullstring (pull string, pull-string), pullcord (pull cord, pull-cord), or pullchain (pull-chain, pull chain) is a string, cord, or chain wound on a spring-loaded spindle that engages a mechanism when it is pulled. It is most commonly used in toys and motorized equipment. More generally and commonly, a] pulled my dress up.
# The book publisher [WikiSearch(ww norton company)→ Milton H. Erickson. "Conversations with Milton H. Erickson, M.D.", edited by Jay Haley (WW Norton and Company: New York, 1999) "Milton H. Erickson, M.D.: In His Own Voice", edited by Jay Haley and co-edited by Madeleine Richeport (WW Norton & Company: New York, 1991).] W.W. Norton was her grandfather.

# %%
df.head(20)
# Out:
#                                                     url  \
# 628   http://www.idaillinois.org/cdm/ref/collection/...
# 143   https://www.aoc.gov/art/national-statuary-hall...
# 1309  https://diversityflags.com/de-at/1241/wyoming-...
# 1310  https://diversityflags.com/de-at/1241/wyoming-...
# 1308  https://diversityflags.com/de-at/1241/wyoming-...
# 2293       https://www.history.noaa.gov/war/ww1_20.html
# 2295       https://www.history.noaa.gov/war/ww1_20.html
# 2656       https://www.history.noaa.gov/war/ww1_20.html
# 2286       https://www.history.noaa.gov/war/ww1_20.html
# 2287       https://www.history.noaa.gov/war/ww1_20.html
# 2288       https://www.history.noaa.gov/war/ww1_20.html
# 2289       https://www.history.noaa.gov/war/ww1_20.html
# 2290       https://www.history.noaa.gov/war/ww1_20.html
# 2291       https://www.history.noaa.gov/war/ww1_20.html
# 2292       https://www.history.noaa.gov/war/ww1_20.html
# 2294       https://www.history.noaa.gov/war/ww1_20.html
# 2553  https://tiffanyoaks.maac.com/tennessee/nashville/
# 2366  https://www.zerohanger.com/top-10-greatest-ind...
# 1453   https://www.history.noaa.gov/cgsbios/bioc14.html
# 369                   https://klab.rw/public/member/259
#
#                                                    text  \
# 628   PROMOTIONS (beginning with original rank) Succ...
# 143   Domestically, he sponsored bills that created ...
# 1309  They chose a drawing by Verna Keays, a recent ...
# 1310  They chose a drawing by Verna Keays, a recent ...
# 1308  They chose a drawing by Verna Keays, a recent ...
# 2293  During the month of September positions were o...
# 2295  During the month of September positions were o...
# 2656  During the latter part of May the regiment cha...
# 2286  During the month of September positions were o...
# 2287  During the month of September positions were o...
# 2288  During the month of September positions were o...
# 2289  During the month of September positions were o...
# 2290  During the month of September positions were o...
# 2291  During the month of September positions were o...
# 2292  During the month of September positions were o...
# 2294  During the month of September positions were o...
# 2553  From the arts and culture it's known for to th...
# 2366  He is a five-time All-Australian and may come ...
# 1453                                            18, No.
# 369   I take a multidisciplinary approach to develop...
#
#                                          API_calls_text  \
# 628   PROMOTIONS (beginning with original rank) Succ...
# 143   Domestically, he sponsored bills that created ...
# 1309  They chose a drawing by [WikiSearch(verna keay...
# 1310  They chose a drawing by [WikiSearch(verna keay...
# 1308  They chose a drawing by [WikiSearch(page)] Ver...
# 2293  During the month of September positions were o...
# 2295  During the month of September [WikiSearch(sept...
# 2656  During the latter part of May the regiment cha...
# 2286  During the month of [WikiSearch(september)] Se...
# 2287  During the month of [WikiSearch(september mont...
# 2288  During the month of September positions were o...
# 2289  During the month of September positions were o...
# 2290  During the month of September positions were o...
# 2291  During the month of September positions were o...
# 2292  During the month of September positions were o...
# 2294  During the month of September positions were o...
# 2553  From the arts and culture it's known for [Wiki...
# 2366  He is a five-time [WikiSearch(all-australian)]...
# 1453                           18, [WikiSearch(18)] No.
# 369   I take a multidisciplinary approach to develop...
#
#                                  API_call_response_text  position  \
# 628   PROMOTIONS (beginning with original rank) Succ...       NaN
# 143   Domestically, he sponsored bills that created ...       NaN
# 1309  They chose a drawing by [WikiSearch(verna keay...       NaN
# 1310  They chose a drawing by [WikiSearch(verna keay...       NaN
# 1308  They chose a drawing by [WikiSearch(page)→ Lis...       NaN
# 2293  During the month of September positions were o...       NaN
# 2295  During the month of September [WikiSearch(sept...       NaN
# 2656  During the latter part of May the regiment cha...       NaN
# 2286  During the month of [WikiSearch(september)→ At...       NaN
# 2287  During the month of [WikiSearch(september mont...       NaN
# 2288  During the month of September positions were o...       NaN
# 2289  During the month of September positions were o...       NaN
# 2290  During the month of September positions were o...       NaN
# 2291  During the month of September positions were o...       NaN
# 2292  During the month of September positions were o...       NaN
# 2294  During the month of September positions were o...       NaN
# 2553  From the arts and culture it's known for [Wiki...       NaN
# 2366  He is a five-time [WikiSearch(all-australian)→...       NaN
# 1453  18, [WikiSearch(18)→ 2016 Masters Tournament. ...       NaN
# 369   I take a multidisciplinary approach to develop...       NaN
#
#       loss_improvement                                         arg_cohort  \
# 628           1.844487  ['val', 'rank', 'rank', 'rank', 'original', 'n...
# 143           1.094933  ['term', '1', 'who what', 'beginnings', 'depar...
# 1309          3.228760  ['page', 'term', 'wikipediacom', 'nameofartifa...
# 1310          4.226761  ['page', 'term', 'wikipediacom', 'nameofartifa...
# 1308          1.277151  ['page', 'term', 'wikipediacom', 'nameofartifa...
# 2293          2.656330  ['september', 'september', 'term', 'september ...
# 2295          4.211182  ['september', 'september', 'term', 'september ...
# 2656          2.072550  ['foret du puvenelle', 'foret du puvenelle', '...
# 2286          1.793331  ['september', 'september', 'term', 'september ...
# 2287          0.946161  ['september', 'september', 'term', 'september ...
# 2288          3.164342  ['september', 'september', 'term', 'september ...
# 2289          3.388188  ['september', 'september', 'term', 'september ...
# 2290          3.101745  ['september', 'september', 'term', 'september ...
# 2291          3.395577  ['september', 'september', 'term', 'september ...
# 2292          3.514470  ['september', 'september', 'term', 'september ...
# 2294          3.102357  ['september', 'september', 'term', 'september ...
# 2553          4.996248  ['', 'term', 'term', 'term', 'term', 'cons', '...
# 2366          1.979773  ['', '', '1001', '', 'all-australian', 'all-au...
# 1453          1.084492  ['18', '', '18', 'no', '', 'number18', 'no rec...
# 369           0.746855  ['', 'order', 'term', 'term', 'work', 'data', ...
#
#                                                raw_arg  \
# 628              private life,1st class,rank class(fff
# 143                                ["children's bureau
# 1309                              "Verna Keays artwork
# 1310                                   ''Verna Keays''
# 1308                                              page
# 2293                       Meuse-Argonne "heavy action
# 2295  September Rambucourt drive argonne drive meaning
# 2656                       posta pont a mousson greece
# 2286                                         September
# 2287                                   September month
# 2288                                        Rambucourt
# 2289                               Meuse Argonne drive
# 2290                                    Rambucourt + 1
# 2291                                     Meuse-Argonne
# 2292                               Meuse-Argonne drive
# 2294                   Meuse-Argonne drive api example
# 2553              "Where to buy cheap in Victoria BC?"
# 2366                                    All-Australian
# 1453                                                18
# 369                                     -"data science
#
#                                          processed_arg  \
# 628                 private life1st classrank classfff
# 143                                   childrens bureau
# 1309                               verna keays artwork
# 1310                                       verna keays
# 1308                                              page
# 2293                        meuse-argonne heavy action
# 2295  september rambucourt drive argonne drive meaning
# 2656                         posta pont mousson greece
# 2286                                         september
# 2287                                   september month
# 2288                                        rambucourt
# 2289                               meuse argonne drive
# 2290                                      rambucourt 1
# 2291                                     meuse-argonne
# 2292                               meuse-argonne drive
# 2294                   meuse-argonne drive api example
# 2553                       where buy cheap victoria bc
# 2366                                    all-australian
# 1453                                                18
# 369                                      -data science
#
#                                                   title  ... length nlines  \
# 628   Individual service record for Elmer David Ray ...  ...   2871      8
# 143      William Edgar Borah | Architect of the Capitol  ...   1490      5
# 1309         Wyoming US State flag | Flags of the World  ...   1822      6
# 1310         Wyoming US State flag | Flags of the World  ...   1822      6
# 1308         Wyoming US State flag | Flags of the World  ...   1822      6
# 2293  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2295  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2656  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2286  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2287  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2288  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2289  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2290  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2291  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2292  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2294  NOAA History - A Nation at War/World Wars/Worl...  ...  12455     51
# 2553  Luxury Apartments for Rent in Nashville, Tenne...  ...    320      1
# 2366  Top 10 Greatest Indigenous AFL Players | Zero ...  ...   4801     27
# 1453  NOAA History - Profiles in Time/C&GS Biographi...  ...   1510      3
# 369              kLab | Open Space for IT Entrepreneurs  ...   1085      2
#
#              source_domain                                         cc_segment  \
# 628    www.idaillinois.org  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 143            www.aoc.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 1309    diversityflags.com  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 1310    diversityflags.com  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 1308    diversityflags.com  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2293  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2295  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2656  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2286  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2287  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2288  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2289  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2290  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2291  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2292  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2294  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2553  tiffanyoaks.maac.com  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 2366    www.zerohanger.com  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 1453  www.history.noaa.gov  crawl-data/CC-MAIN-2019-09/segments/1550247481...
# 369                klab.rw  crawl-data/CC-MAIN-2019-09/segments/1550247481...
#
#      original_nlines original_length  language  language_score perplexity  \
# 628              287           11214        en            0.72       23.6
# 143              259            6757        en            0.98       68.5
# 1309             107            5628        en            0.96       80.9
# 1310             107            5628        en            0.96       80.9
# 1308             107            5628        en            0.96       80.9
# 2293              58           12762        en            0.98       88.1
# 2295              58           12762        en            0.98       88.1
# 2656              58           12762        en            0.98       88.1
# 2286              58           12762        en            0.98       88.1
# 2287              58           12762        en            0.98       88.1
# 2288              58           12762        en            0.98       88.1
# 2289              58           12762        en            0.98       88.1
# 2290              58           12762        en            0.98       88.1
# 2291              58           12762        en            0.98       88.1
# 2292              58           12762        en            0.98       88.1
# 2294              58           12762        en            0.98       88.1
# 2553              99            1706        en            0.97       96.5
# 2366             217            8390        en            0.98       97.6
# 1453               8            1776        en            0.98      102.2
# 369               19            1431        en            0.89      103.1
#
#       bucket
# 628     head
# 143     head
# 1309    head
# 1310    head
# 1308    head
# 2293    head
# 2295    head
# 2656    head
# 2286    head
# 2287    head
# 2288    head
# 2289    head
# 2290    head
# 2291    head
# 2292    head
# 2294    head
# 2553    head
# 2366    head
# 1453    head
# 369     head
#
# [20 rows x 22 columns]

# %%
# Create a list of coordinates from the df, with x being the loss_improvement and y being the perplexity:
x = df['loss_improvement']
y = df['perplexity']

# Convert to list:
x = x.tolist()
y = [float(num) for num in y.tolist()]

print(x[:5])
print(y[:5])

# Plot the coordinates:
import matplotlib.pyplot as plt
plt.scatter(x, y)
plt.show()
# Out:
# [1.844487190246582, 1.0949325561523438, 3.228760004043579, 4.2267608642578125, 1.277151107788086]
# [23.6, 68.5, 80.9, 80.9, 80.9]

# %%
# Filter df by perplexity < 100, and sort by loss_improvement:
df = df[df['perplexity'] < 100]
df.sort_values(by=['loss_improvement'], inplace=True, ascending=False)

df.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Filter df by perplexity < 100, and sort by loss_improvement:
# ----> 2 df = df[df['perplexity'] < 100]
#       3 df.sort_values(by=['loss_improvement'], inplace=True, ascending=True)
#       5 df.head(20)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:82, in comp_method_OBJECT_ARRAY(op, x, y)
#      80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
# ---> 82     result = libops.scalar_compare(x.ravel(), y, op)
#      83 return result.reshape(x.shape)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
