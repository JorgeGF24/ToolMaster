# %%
import pandas as pd

df = pd.read_csv('0.csv')

df.head()

# sort df by column "loss_improvement"
df.sort_values(by=['perplexity'], inplace=True, ascending=True)

# %%
import matplotlib

# Print text of second row of df:
print(df.iloc[0]['url'])

# Iterate through first 20 rows of df:
for i in range(300,320):
    print(df.iloc[i]['API_call_response_text'])
# Out:
# http://ddotomen.co/blog/page/2255/
# 00 pm - 05:30 pm (Mon) Feb 26, 2019 at [Calculator(2019-02070500)→ -2068481.0] 04:00 pm - 05:30 pm (Tue) Feb 27, 2019 at 04:00 pm - 05:30 pm (Wed) Mar 1, 2019 at 04:00 pm - 05:30 pm (Fri
# 00 pm - 05:30 pm (Mon) Feb 26, 2019 at [Calculator(0400/30)→ 13.33] 04:00 pm - 05:30 pm (Tue) Feb 27, 2019 at 04:00 pm - 05:30 pm (Wed) Mar 1, 2019 at 04:00 pm - 05:30 pm (Fri
# 00 pm - 05:30 pm (Mon) Feb 26, 2019 at [Calculator(2019-2020)→ -1.0] 04:00 pm - 05:30 pm (Tue) Feb 27, 2019 at 04:00 pm - 05:30 pm (Wed) Mar 1, 2019 at 04:00 pm - 05:30 pm (Fri
# The classification of these cases and deaths are as follows: confirmed, [Calculator(172+71)→ 243.0] 172 cases and 108 deaths; probable, 71 cases and 62 deaths; and suspected, 48 cases and 23 deaths.
# The classification of these cases and deaths are as follows: confirmed, [Calculator(172/365)→ 0.47] 172 cases and 108 deaths; probable, 71 cases and 62 deaths; and suspected, 48 cases and 23 deaths.
# li Addevishwanathapura village Sno [Calculator(64/1126/6/33/36/48/6)→ 0.05] 64/1 site 6 katha 3860/1126/6 Doddaballapura taluk kasaba hobli Raghunathapura and Thammashettyhalli village Sno 33, 36, 48/6,
# She eventually served 15 years of the 40 year sentence and was released from state prison on [Calculator(2008-19)→ 1989.0] January 1, 2008.
# li Addevishwanathapura village Sno 64/1 site 6 [Calculator(6362/1126)→ 5.65] katha 3860/1126/6 Doddaballapura taluk kasaba hobli Raghunathapura and Thammashettyhalli village Sno 33, 36, 48/6,
# Retrieved from [Calculator(4183/9)→ 464.78] "https://marilyn.fandom.com/wiki/List_of_documentaries?oldid=4183"
# The Treasury: 51, 63, 80, 124, 124A, 145, 166, 174, 174e, 197, [Calculator(174/174)→ 1.0] 1n, 2n, 3n, 4n, 5n, 6n Fullerton Sq: 10, 10e, 57, 70, 100, 107,
# Winds from [Calculator(4+6.4*6.4)→ 44.96] SW to W at 4 to 8 mph (6.4 to 12.9 kph).Night - Cloudy.
# Recent statistics show that more than 700, 000 people in Ireland are effected by these conditions and [Calculator(70000000/500000)→ 140.0] […] We are saddened to report the death of Dr. Lewis Rowland Professor of Neurology, aged 91, formerly of Columbia University, New York.
# Recent statistics show that more than 700, 000 people in Ireland are effected by these conditions and [Calculator(700000/4)→ 175000.0] […] We are saddened to report the death of Dr. Lewis Rowland Professor of Neurology, aged 91, formerly of Columbia University, New York.
# Recent statistics show that more than 700, 000 people in Ireland are effected by these conditions and [Calculator(702/700)→ 1.0] […] We are saddened to report the death of Dr. Lewis Rowland Professor of Neurology, aged 91, formerly of Columbia University, New York.
# Recent statistics show that more than 700, 000 people in Ireland are effected by these conditions and [Calculator(13/1000/20)→ 0.26] […] We are saddened to report the death of Dr. Lewis Rowland Professor of Neurology, aged 91, formerly of Columbia University, New York.
# Recent statistics show that more than 700, 000 people in Ireland are effected by these conditions and [Calculator(700000/10000)→ 70.0] […] We are saddened to report the death of Dr. Lewis Rowland Professor of Neurology, aged 91, formerly of Columbia University, New York.
# Recent statistics show that more than 700, 000 people in Ireland are effected by these conditions and [Calculator(700000/500000)→ 1.4] […] We are saddened to report the death of Dr. Lewis Rowland Professor of Neurology, aged 91, formerly of Columbia University, New York.
# Retrieved from [Calculator(44/3)→ 14.67] "https://en.wikipedia.org/w/index.php?title=Fatma_Ceren_Necipoğlu&oldid=880235831" Turkish expatriates in the United States Turkish harpists Turkish classical musicians Deutsche Schule Istanbul
# Retrieved from [Calculator(1465265761-2807573858)→ -1342308097.0] "https://en.wikipedia.org/w/index.php?title=Fatma_Ceren_Necipoğlu&oldid=880235831" Turkish expatriates in the United States Turkish harpists Turkish classical musicians Deutsche Schule Istanbul
# Retrieved from [Calculator(88/19876024625)→ 0.0] "https://en.wikipedia.org/w/index.php?title=Fatma_Ceren_Necipoğlu&oldid=880235831" Turkish expatriates in the United States Turkish harpists Turkish classical musicians Deutsche Schule Istanbul

# %%
df.head(20)
# Out:
#                                                     url  \
# 4605                 http://ddotomen.co/blog/page/2255/
# 4606                 http://ddotomen.co/blog/page/2255/
# 4607                 http://ddotomen.co/blog/page/2255/
# 4608                 http://ddotomen.co/blog/page/2255/
# 585   http://www.hiphopmagz.com/the-top-20-latin-son...
# 1290  https://www.photocreationsbysteveleinbach.com/...
# 1292  https://www.photocreationsbysteveleinbach.com/...
# 1291  https://www.photocreationsbysteveleinbach.com/...
# 4825  http://dickconley.tripod.com/Allenfamily/id3.html
# 4824  http://dickconley.tripod.com/Allenfamily/id3.html
# 4823  http://dickconley.tripod.com/Allenfamily/id3.html
# 4822  http://dickconley.tripod.com/Allenfamily/id3.html
# 852   http://dickconley.tripod.com/Allenfamily/id3.html
# 850   http://dickconley.tripod.com/Allenfamily/id3.html
# 412   http://dickconley.tripod.com/Allenfamily/id3.html
# 1133  http://dickconley.tripod.com/Allenfamily/id3.html
# 2204  http://dickconley.tripod.com/Allenfamily/id3.html
# 4826  http://dickconley.tripod.com/Allenfamily/id3.html
# 2203  http://dickconley.tripod.com/Allenfamily/id3.html
# 2202  http://dickconley.tripod.com/Allenfamily/id3.html
#
#                                                    text  \
# 4605  6446546646746846947047147247347447547647747847...
# 4606  6446546646746846947047147247347447547647747847...
# 4607  6446546646746846947047147247347447547647747847...
# 4608  6446546646746846947047147247347447547647747847...
# 585   1 on graph dated Sept. 28, 2013, staying in th...
# 1290  , 2 4x6, 18 wallets #3...........................
# 1292  , 2 4x6, 18 wallets #3...........................
# 1291  , 2 4x6, 18 wallets #3...........................
# 4825   6 Kathie B. Kirkindall .........................
# 4824   6 Kathie B. Kirkindall .........................
# 4823   6 Kathie B. Kirkindall .........................
# 4822   6 Kathie B. Kirkindall .........................
# 852   .Ch., Roseville, MI .............................
# 850   .Ch., Roseville, MI .............................
# 412   ley Born: 28 August 1959 in Myrtle Beach AFB, ...
# 1133  Born: 24 July 1931 .................... 4 Clar...
# 2204  : 12 April 1982 .................................
# 4826   6 Kathie B. Kirkindall .........................
# 2203  : 12 April 1982 .................................
# 2202  : 12 April 1982 .................................
#
#                                          API_calls_text  \
# 4605  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...
# 4606  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...
# 4607  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...
# 4608  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...
# 585   1 on graph dated Sept. 28, 2013, staying in th...
# 1290  , [Calculator(2+4*6)] 2 4x6, 18 wallets #3.......
# 1292  , 2 [Calculator(4*6)] 4x6, 18 wallets #3.........
# 1291  , 2 [Calculator(4*6-500)] 4x6, 18 wallets #3.....
# 4825   leaving on 17 March and returning on 26 March...
# 4824   leaving on 17 March and returning on 26 March...
# 4823   leaving on 17 March and returning on 26 March...
# 4822   leaving on 17 March and returning on 26 March...
# 852   .Ch., Roseville, MI..............................
# 850   .Ch., Roseville, MI..............................
# 412   ley Born: 28 August 1959 in Myrtle Beach AFB, ...
# 1133  Born: 24 July 1931.................... 4 Clare...
# 2204  : 12 April 1982..................................
# 4826   leaving on 17 March and returning on 26 March...
# 2203  : [Calculator(12041982+16)] 12 April 1982........
# 2202  : [Calculator(1982/4)] 12 April 1982.............
#
#                                  API_call_response_text  position  \
# 4605  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...       NaN
# 4606  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...       NaN
# 4607  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...       NaN
# 4608  720 Two Guys One Bike Relay 2 00:21:09 00:34:3...       NaN
# 585   1 on graph dated Sept. 28, 2013, staying in th...       NaN
# 1290  , [Calculator(2+4*6)→ 26.0] 2 4x6, 18 wallets ...       NaN
# 1292  , 2 [Calculator(4*6)→ 24.0] 4x6, 18 wallets #3...       NaN
# 1291  , 2 [Calculator(4*6-500)→ -476.0] 4x6, 18 wall...       NaN
# 4825   leaving on 17 March and returning on 26 March...       NaN
# 4824   leaving on 17 March and returning on 26 March...       NaN
# 4823   leaving on 17 March and returning on 26 March...       NaN
# 4822   leaving on 17 March and returning on 26 March...       NaN
# 852   .Ch., Roseville, MI..............................       NaN
# 850   .Ch., Roseville, MI..............................       NaN
# 412   ley Born: 28 August 1959 in Myrtle Beach AFB, ...       NaN
# 1133  Born: 24 July 1931.................... 4 Clare...       NaN
# 2204  : 12 April 1982..................................       NaN
# 4826   leaving on 17 March and returning on 26 March...       NaN
# 2203  : [Calculator(12041982+16)→ 12041998.0] 12 Apr...       NaN
# 2202  : [Calculator(1982/4)→ 495.5] 12 April 1982......       NaN
#
#       loss_improvement                                         arg_cohort  \
# 4605          0.667646  ['', '720', '720', '720', '720', '720', '720',...
# 4606          0.875380  ['', '720', '720', '720', '720', '720', '720',...
# 4607          1.214628  ['', '720', '720', '720', '720', '720', '720',...
# 4608          1.397631  ['', '720', '720', '720', '720', '720', '720',...
# 585           0.629364  ['4', '17', '4', '4', '4', '4', '4', '', '2013...
# 1290          1.566080  ['2', '2', '90/2', '45/2', '476-12', '18-40', ...
# 1292          1.100467  ['2', '2', '90/2', '45/2', '476-12', '18-40', ...
# 1291          1.048649  ['2', '2', '90/2', '45/2', '476-12', '18-40', ...
# 4825          0.544945  ['340', '340-330', '34/340', '340/15', '340-33...
# 4824          0.559329  ['340', '340-330', '34/340', '340/15', '340-33...
# 4823          0.569384  ['340', '340-330', '34/340', '340/15', '340-33...
# 4822          1.928226  ['340', '340-330', '34/340', '340/15', '340-33...
# 852           0.954939  ['', '6+12', '2000-1994', '1968-1960', '6-1', ...
# 850           0.798429  ['', '6+12', '2000-1994', '1968-1960', '6-1', ...
# 412           0.692299  ['28', '', '2008-1959', '8*7', '1959/20', '28/...
# 1133          0.994934  ['21', '4', '24', '1931', '2701', '31-24', '27...
# 2204          0.742456  ['22', '1982-1980', '2+0', '5-12', '1982/4', '...
# 4826          0.805750  ['340', '340-330', '34/340', '340/15', '340-33...
# 2203          1.563301  ['22', '1982-1980', '2+0', '5-12', '1982/4', '...
# 2202          1.220997  ['22', '1982-1980', '2+0', '5-12', '1982/4', '...
#
#                  raw_arg processed_arg  \
# 4605             720+718       720+718
# 4606             720/802       720/802
# 4607              718+10        718+10
# 4608           720+2*348     720+2*348
# 585                  4/1           4/1
# 1290               2+4*6         2+4*6
# 1292                 4*6           4*6
# 1291             4x6-500       4*6-500
# 4825            10080/42      10080/42
# 4824            59 + 112        59+112
# 4823             339+332       339+332
# 4822              340/15        340/15
# 852            1908-2010     1908-2010
# 850            2010-2012     2010-2012
# 412              599/283       599/283
# 1133  4+Minnie Sharron+5          4++5
# 2204   1982+Marcella2013     1982+2013
# 4826          59+17·F/22      59+17/22
# 2203         12041982+16   12041982+16
# 2202              1982/4        1982/4
#
#                                                   title  ... length nlines  \
# 4605                Blog - Page 2255 of 4375 - DDotOmen  ...  20406     13
# 4606                Blog - Page 2255 of 4375 - DDotOmen  ...  20406     13
# 4607                Blog - Page 2255 of 4375 - DDotOmen  ...  20406     13
# 4608                Blog - Page 2255 of 4375 - DDotOmen  ...  20406     13
# 585   The Top 20 Latin Songs of All Time on the Bill...  ...   7793     52
# 1290        Services — PhotoCreations by Steve Leinbach  ...   2259     35
# 1292        Services — PhotoCreations by Steve Leinbach  ...   2259     35
# 1291        Services — PhotoCreations by Steve Leinbach  ...   2259     35
# 4825                       Douglass Allen's Descendants  ...  95509   1241
# 4824                       Douglass Allen's Descendants  ...  95509   1241
# 4823                       Douglass Allen's Descendants  ...  95509   1241
# 4822                       Douglass Allen's Descendants  ...  95509   1241
# 852                        Douglass Allen's Descendants  ...  95509   1241
# 850                        Douglass Allen's Descendants  ...  95509   1241
# 412                        Douglass Allen's Descendants  ...  95509   1241
# 1133                       Douglass Allen's Descendants  ...  95509   1241
# 2204                       Douglass Allen's Descendants  ...  95509   1241
# 4826                       Douglass Allen's Descendants  ...  95509   1241
# 2203                       Douglass Allen's Descendants  ...  95509   1241
# 2202                       Douglass Allen's Descendants  ...  95509   1241
#
#                               source_domain  \
# 4605                            ddotomen.co
# 4606                            ddotomen.co
# 4607                            ddotomen.co
# 4608                            ddotomen.co
# 585                      www.hiphopmagz.com
# 1290  www.photocreationsbysteveleinbach.com
# 1292  www.photocreationsbysteveleinbach.com
# 1291  www.photocreationsbysteveleinbach.com
# 4825                  dickconley.tripod.com
# 4824                  dickconley.tripod.com
# 4823                  dickconley.tripod.com
# 4822                  dickconley.tripod.com
# 852                   dickconley.tripod.com
# 850                   dickconley.tripod.com
# 412                   dickconley.tripod.com
# 1133                  dickconley.tripod.com
# 2204                  dickconley.tripod.com
# 4826                  dickconley.tripod.com
# 2203                  dickconley.tripod.com
# 2202                  dickconley.tripod.com
#
#                                              cc_segment original_nlines  \
# 4605  crawl-data/CC-MAIN-2019-09/segments/1550247490...              66
# 4606  crawl-data/CC-MAIN-2019-09/segments/1550247490...              66
# 4607  crawl-data/CC-MAIN-2019-09/segments/1550247490...              66
# 4608  crawl-data/CC-MAIN-2019-09/segments/1550247490...              66
# 585   crawl-data/CC-MAIN-2019-09/segments/1550247481...              97
# 1290  crawl-data/CC-MAIN-2019-09/segments/1550247481...              60
# 1292  crawl-data/CC-MAIN-2019-09/segments/1550247481...              60
# 1291  crawl-data/CC-MAIN-2019-09/segments/1550247481...              60
# 4825  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 4824  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 4823  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 4822  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 852   crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 850   crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 412   crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 1133  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 2204  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 4826  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 2203  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
# 2202  crawl-data/CC-MAIN-2019-09/segments/1550247494...            1266
#
#      original_length  language  language_score perplexity  bucket
# 4605           21471        en            0.65        3.3    head
# 4606           21471        en            0.65        3.3    head
# 4607           21471        en            0.65        3.3    head
# 4608           21471        en            0.65        3.3    head
# 585             8995        en            0.70       11.1    head
# 1290            2875        en            0.57       12.1    head
# 1292            2875        en            0.57       12.1    head
# 1291            2875        en            0.57       12.1    head
# 4825           96408        en            0.57       15.4    head
# 4824           96408        en            0.57       15.4    head
# 4823           96408        en            0.57       15.4    head
# 4822           96408        en            0.57       15.4    head
# 852            96408        en            0.57       15.4    head
# 850            96408        en            0.57       15.4    head
# 412            96408        en            0.57       15.4    head
# 1133           96408        en            0.57       15.4    head
# 2204           96408        en            0.57       15.4    head
# 4826           96408        en            0.57       15.4    head
# 2203           96408        en            0.57       15.4    head
# 2202           96408        en            0.57       15.4    head
#
# [20 rows x 22 columns]

# %%
# Create a list of coordinates from the df, with x being the loss_improvement and y being the perplexity:
x = df['loss_improvement']
y = df['perplexity']

# Convert to list:
x = x.tolist()
y = [float(num) for num in y.tolist()]

print(x[:5])
print(y[:5])

# Plot the coordinates:
import matplotlib.pyplot as plt
plt.scatter(x, y)
plt.show()
# Out:
# [0.6676464080810547, 0.8753795623779297, 1.2146282196044922, 1.3976306915283203, 0.629364013671875]
# [3.3, 3.3, 3.3, 3.3, 11.1]

# %%
# Filter df by perplexity < 100, and sort by loss_improvement:
df = df[df['perplexity'] < 100]
df.sort_values(by=['loss_improvement'], inplace=True, ascending=False)

df.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Filter df by perplexity < 100, and sort by loss_improvement:
# ----> 2 df = df[df['perplexity'] < 100]
#       3 df.sort_values(by=['loss_improvement'], inplace=True, ascending=True)
#       5 df.head(20)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:82, in comp_method_OBJECT_ARRAY(op, x, y)
#      80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
# ---> 82     result = libops.scalar_compare(x.ravel(), y, op)
#      83 return result.reshape(x.shape)
#
# File /vol/bitbucket/jg2619/toolformer-luci/oldtoolvenv/lib/python3.10/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
